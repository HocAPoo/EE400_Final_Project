# %%
#Import necessary libraries
import pandas as pd

# Load dataset from a designated path and MS Excel file into a dataframe called "data"
file_path = '/Users/airturtle/Desktop/UW/Teaching/NLP_Course/Datasets/PeerSupport/PeerSupport_Level1.xlsx'
data_prelim = pd.read_excel(file_path)
data = data_prelim [["PeerSupportResponse"]] #"PeerSupportResponse" is a column label in the .xlsx file

# Convert all elements in the 'PeerSupportResponse" column to strings using .loc
data.loc[:, 'PeerSupportResponse'] = data['PeerSupportResponse'].astype(str)

#Print the length of the data (number of responses)
#n = 250 for PeerSupport_Level1 data
print (len(data))

#Print data to sanity check that the data has been loaded properly
print (data)
# Out:
# 250
#                                    PeerSupportResponse
# 0                                   Ask good questions
# 1    Reduce the amount of talking and other distrac...
# 2                    ask more questions during lecture
# 3                              Bring up more questions
# 4     Form study groups to understand class materials.
# ..                                                 ...
# 245                 Ask all the questions all the time
# 246  Asking questions during lectures can help me f...
# 247  Ask questions during lectures if anything is n...
# 248  Turning on cameras helps to create the feeling...
# 249  Make sure to mute their mics when they are sup...
#
# [250 rows x 1 columns]
